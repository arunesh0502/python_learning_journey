# %%
age="20"
age_int=int(age)
age_next=int(age)+1
print('Current Age:', age_int)
print("Age next year:", age_next)
message="You will be "+ str(age_next) +" next year"
print(message)
# Out:
# Current Age: 20
# Age next year: 21
# You will be 21 next year

# %%
price=19.2343
percent=0.1234
print(f"Price is ${price:.2f}")
print(f"Percent is {percent:.2%}")
# Out:
# Price is $19.23
# Percent is 12.34%

# %%
name = "Alice"
age = 22
gpa = 3.85
print("Student:", name, " \nAge:", age, " \nGPA:", gpa)
# Out:
# Student: Alice
# Age: 22
# GPA: 3.85

# %%
total_seconds = 3428583
days=total_seconds//86400
rem=total_seconds%86400
hours=rem//3600
remaining=rem%3600
minutes=remaining//60
seconds=remaining%60
print(f'{total_seconds} seconds = {days}d:{hours}h:{minutes}m:{seconds}s')
# Out:
# 3428583 seconds = 39d:16h:23m:3s
